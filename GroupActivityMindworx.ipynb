# %% [markdown]
# <a href="https://colab.research.google.com/github/merabgithub/Introducing-pandas-with-Mr-Baholo-via-Mindworx/blob/main/GroupActivityMindworx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **Reading** my **excel** file to a **CSV**

# %%
file_path = "/content/sample_data/voting_election_results.xlsx"

# %%
df = pd.read_excel(file_path)

# %%
df
# Out:
#           NAME    SURNAME             GENDER   AGE  EMPLOYED  MONTHLYSALARY  \
# 0    Christine     Oliver         Non-binary  45.3     False            NaN
# 1       Gloria     Barker  Prefer not to say  20.4     False           0.00
# 2     Michelle       Page              Other  40.2     False           0.00
# 3      Antonio  Fernandez             Female   NaN      True            NaN
# 4         Luis     Thomas                NaN  77.5     False           0.00
# ..         ...        ...                ...   ...       ...            ...
# 495    Melanie   Martinez  Prefer not to say   NaN     False           0.00
# 496     Nathan      Davis                NaN  50.3      True        5295.06
# 497    Deborah      Allen             Female   NaN      True            NaN
# 498    Anthony  Patterson         Non-binary  46.3     False           0.00
# 499     Joanne     Valdez             Female   NaN     False           0.00
#
#      VOTED POLITICAL PARTY
# 0      NaN             NaN
# ...

# %%
df.head()
# Out:
#         NAME    SURNAME             GENDER   AGE  EMPLOYED  MONTHLYSALARY  \
# 0  Christine     Oliver         Non-binary  45.3     False            NaN
# 1     Gloria     Barker  Prefer not to say  20.4     False            0.0
# 2   Michelle       Page              Other  40.2     False            0.0
# 3    Antonio  Fernandez             Female   NaN      True            NaN
# 4       Luis     Thomas                NaN  77.5     False            0.0
#
#    VOTED POLITICAL PARTY
# 0    NaN             NaN
# 1    1.0             ANC
# 2    NaN             NaN
# 3    1.0             NaN
# 4    0.0             NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             500 non-null    object
#  1   SURNAME          500 non-null    object
#  2   GENDER           350 non-null    object
#  3   AGE              350 non-null    float64
#  4   EMPLOYED         500 non-null    bool
#  5   MONTHLYSALARY    350 non-null    float64
#  6   VOTED            350 non-null    float64
#  7   POLITICAL PARTY  178 non-null    object
# dtypes: bool(1), float64(3), object(4)
# memory usage: 28.0+ KB

# %%
df.describe()
# Out:
#               AGE  MONTHLYSALARY       VOTED
# count  350.000000     350.000000  350.000000
# mean    56.191143    5708.195200    0.502857
# std     19.977258    6829.183224    0.500708
# min     18.200000       0.000000    0.000000
# 25%     40.125000       0.000000    0.000000
# 50%     57.750000    1739.660000    1.000000
# 75%     72.375000   12064.727500    1.000000
# max     89.600000   19991.130000    1.000000

# %%
df['VOTED'].describe()
# Out:
# count    350.000000
# mean       0.502857
# std        0.500708
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: VOTED, dtype: float64

# %%
df[['AGE','VOTED']].describe()
# Out:
#               AGE       VOTED
# count  350.000000  350.000000
# mean    56.191143    0.502857
# std     19.977258    0.500708
# min     18.200000    0.000000
# 25%     40.125000    0.000000
# 50%     57.750000    1.000000
# 75%     72.375000    1.000000
# max     89.600000    1.000000

# %%
df[['AGE','VOTED']]
# Out:
#       AGE  VOTED
# 0    45.3    NaN
# 1    20.4    1.0
# 2    40.2    NaN
# 3     NaN    1.0
# 4    77.5    0.0
# ..    ...    ...
# 495   NaN    1.0
# 496  50.3    1.0
# 497   NaN    1.0
# 498  46.3    NaN
# 499   NaN    0.0
#
# [500 rows x 2 columns]

# %%
df['VOTED'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 500 entries, 0 to 499
# Series name: VOTED
# Non-Null Count  Dtype
# --------------  -----
# 350 non-null    float64
# dtypes: float64(1)
# memory usage: 4.0 KB

# %%
df['AGE'].value_counts()
# Out:
# AGE
# 56.3    4
# 36.9    3
# 57.6    3
# 62.4    3
# 50.3    3
#        ..
# 63.1    1
# 84.8    1
# 39.9    1
# 89.6    1
# 46.3    1
# Name: count, Length: 284, dtype: int64

# %%
df['VOTED'].value_counts()
# Out:
# VOTED
# 1.0    176
# 0.0    174
# Name: count, dtype: int64

# %%
df['POLITICAL PARTY'].value_counts()
# Out:
# POLITICAL PARTY
# ANC    39
# IFP    37
# EFF    37
# DA     33
# FFP    32
# Name: count, dtype: int64
